# %%
import sys
sys.path.append('../src')

# %%
import numpy as np
from integrator import ComplexIntegrator


a = -0.1
b = 0.1
c = -1j

def param(x):
    return x[:,0]*(b-a)+a, (b-a)


def foo(x):
    return 1/(x-c)

i = ComplexIntegrator(1)

print(i.integrate(foo, param))

print(np.log(b-c) - np.log(a-c))
# Out:
# ComplexIntegratorResult:
# value = (-0.000043±0.000036) + i(-0.199334±0.000003)
# relative absolute error = 0.018% , convergence=0.058, iters=100000
# -0.19933730498232416j
