# %%
import sys
sys.path.append("../src")

# %%
from context import TriangleIntegrandContext, TriangleIntegrandEvaluator
from integrand_builder import IntegrandBuilder
from wrapped_eval import WrappedEvaluator
from typing import Callable
import numpy as np

# %%
ctx = TriangleIntegrandContext()

# %%
# Out:
# Compiling evaluator: "a"
# Done!
# Compiling evaluator: "b"
# Done!
