# %%
import sys
from pathlib import Path

parent = Path.cwd().parent
sys.path.append(str(parent))

# %%
from src.integrand_builder import ContextManager
import oneloop_bridge
import matplotlib.pyplot as plt
# do this to trigger the banner here so it doesn't get in the way later
oneloop_bridge.set_renormalization_scale(1.0)
# Out:
# ########################################################################
# #                                                                      #
# #                        You are using OneLOop                         #
# #                                                                      #
# # for the evaluation of 1-loop scalar 1-, 2-, 3- and 4-point functions #
# #                                                                      #
# # author: Andreas van Hameren <hamerenREMOVETHIS@ifj.edu.pl>           #
# #   date: 2024-11-23                                                   #
# #                                                                      #
# # Please cite                                                          #
# #    A. van Hameren,                                                   #
# #      Comput.Phys.Commun. 182 (2011) 2427-2438, arXiv:1007.4716       #
# #    A. van Hameren, C.G. Papadopoulos and R. Pittau,                  #
# #      JHEP 0909:106,2009, arXiv:0903.4665                             #
# # in publications with results obtained with the help of this program. #
# #                                                                      #
# ########################################################################

# %%
cm = ContextManager(force_rebuild = True)
# Out:
# Compiling evaluator: "combined_result"
# Done!

# %%
import numpy as np

m = 0.1-0.01j
cm.masses = [m,0.9*m,1.1*m]
cm.origin = np.array([0,1,0,0])
cm.get_threshold_report()
cm.a = 1
cm.b = 0
cm.c = 0
cm.plot_planes((-8,8), (-8,8))
plt.show()
cm.plot_threshold_subtraction((-2.2,2.2), (-2.2,2.2))
plt.show()
cm.plot_integrated_counterterm()
plt.show()
# Out:
# q = [-1.  -0.5  0.   0. ]
# q² = 0.75
# E-surface value at origin = (-0.8959981818342317-0.010806771447366307j)
# q = [-1.   0.  -0.5  0. ]
# q² = 0.75
# E-surface value at origin = (0.42244453032979123-0.001659819645663991j)
# q = [-2.  -0.5 -0.5  0. ]
# q² = 3.5
# E-surface value at origin = (-2.481557287835977-0.010853048198297684j)

# %%
import numpy as np


m = 0.9-0.01j
cm.masses = [m,m,m]
cm.origin = np.array([0,1,0,0])
cm.get_threshold_report()
cm.a = 1
cm.b = 0
cm.c = 0
cm.plot_planes((-8,8), (-8,8))
plt.show()
cm.plot_threshold_subtraction((-8,8), (-8,8))
plt.show()
cm.plot_integrated_counterterm()
plt.show()
# Out:
# q = [-1.  -0.5  0.   0. ]
# q² = 0.75
# E-surface value at origin = (0.24534187207089442-0.016689749413765168j)
# q = [-1.   0.  -0.5  0. ]
# q² = 0.75
# E-surface value at origin = (1.0216261040413888-0.012058767285764348j)
# q = [-2.  -0.5 -0.5  0. ]
# q² = 3.5
# E-surface value at origin = (-1.4237157680295058-0.01536901787199918j)
